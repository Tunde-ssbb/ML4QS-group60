# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
name_session = "tunde_session_1"

def create_movement_plot(data, name_session):
    # Create subplots
    fig, axs = plt.subplots(4, 1, figsize=(12, 16), sharex=True)

    # First plot: arm acceleration
    axs[0].set_title(name_session)
    axs[0].plot(data['time'], data['arm_acc_x'], "r+", label='x')
    axs[0].plot(data['time'], data['arm_acc_y'], "b+", label='y')
    axs[0].plot(data['time'], data['arm_acc_z'], "g+", label='z')
    axs[0].set_ylabel("arm acceleration (m/s^2)")
    axs[0].legend(loc = 'upper left')

    # Second plot: arm rotation
    axs[1].plot(data['time'], data['arm_gyr_x'], "r+", label='x')
    axs[1].plot(data['time'], data['arm_gyr_y'], "b+", label='y')
    axs[1].plot(data['time'], data['arm_gyr_z'], "g+", label='z')
    axs[1].set_ylabel("arm rotation (rad/s)")
    axs[1].legend(loc = 'upper left')

    # Third plot: leg acceleration
    axs[2].plot(data['time'], data['leg_acc_x'], "r+", label='x')
    axs[2].plot(data['time'], data['leg_acc_y'], "b+", label='y')
    axs[2].plot(data['time'], data['leg_acc_z'], "g+", label='z')
    axs[2].set_ylabel("leg acceleration (m/s^2)")
    axs[2].legend(loc = 'upper left')

    # Fourth plot: leg rotation
    axs[3].plot(data['time'], data['leg_gyr_x'], "r+", label='x')
    axs[3].plot(data['time'], data['leg_gyr_y'], "b+", label='y')
    axs[3].plot(data['time'], data['leg_gyr_z'], "g+", label='z')
    axs[3].set_ylabel("leg rotation (rad/s)")
    axs[3].legend(loc = 'upper left')

    # Set common x-label
    axs[3].set_xlabel("time (min)")

    # Set x-ticks only for the lowest subplot
    for ax in axs[:-1]:
        ax.tick_params(labelbottom=False)

    # Format the x-ticks as integers representing minutes
    axs[3].set_xticks(np.arange(0,3001, 600))
    axs[3].set_xticklabels(range(0,6))


    plt.savefig("./figures/" + name_session )

    # Show plot
    #plt.show()

# %%
def create_performance_plot(data, name_session):
    fig, axs = plt.subplots(3, 1, figsize=(12, 6), sharex=True)

    axs[0].set_title(name_session)
    axs[0].plot(data['time'], data['dist'], 'r.')
    axs[0].set_ylabel("distance (m)")

    axs[1].plot(data['time'], data['pace'], 'b.')
    axs[1].set_ylabel("pace (s/500m)")

    axs[2].plot(data['time'], data['HR'], 'g.')
    axs[2].set_ylabel("heartrate (bpm)")

    axs[2].set_xlabel("time (min)")

    for ax in axs[:-1]:
        ax.tick_params(labelbottom=False)

    # Format the x-ticks as integers representing minutes
    axs[2].set_xticks(np.arange(0,3001, 600))
    axs[2].set_xticklabels(range(0,6))

    plt.savefig("./figures/" + name_session + 'performance')

    #plt.show()

# %%
#distriutions

def create_distribution_plot(data, session_name):

    # Create subplots
    fig, axs = plt.subplots(2, 2, figsize=(16, 16))

    fig.suptitle(session_name)

    # First plot: arm acceleration
    axs[0,0].set_title('arm acceleration')
    axs[0,0].hist(data['arm_acc_x'], bins = 100, alpha = 0.5, label='x')
    axs[0,0].hist(data['arm_acc_y'], bins = 100, alpha = 0.5, label='y')
    axs[0,0].hist(data['arm_acc_z'], bins = 100, alpha = 0.5, label='z')
    axs[0,0].set_xlabel("acceleration (m/s^2)")
    axs[0,0].set_ylabel("frequency")
    axs[0,0].legend(loc = 'upper left')

    # Second plot: arm rotation
    axs[1,0].set_title('arm rotation')
    axs[1,0].hist(data['arm_gyr_x'], bins = 100, alpha = 0.5, label='x')
    axs[1,0].hist(data['arm_gyr_y'], bins = 100, alpha = 0.5, label='y')
    axs[1,0].hist(data['arm_gyr_z'], bins = 100, alpha = 0.5, label='z')
    axs[1,0].set_xlabel("arm rotation (rad/s)")
    axs[1,0].set_ylabel("frequency")
    axs[1,0].legend(loc = 'upper left')

    # Third plot: leg acceleration
    axs[0,1].set_title('leg acceleration')
    axs[0,1].hist(data['leg_acc_x'], bins = 100, alpha = 0.5, label='x')
    axs[0,1].hist(data['leg_acc_y'], bins = 100, alpha = 0.5, label='y')
    axs[0,1].hist(data['leg_acc_z'], bins = 100, alpha = 0.5, label='z')
    axs[0,1].set_xlabel("acceleration (m/s^2)")
    axs[0,1].set_ylabel("frequency")
    axs[0,1].legend(loc = 'upper left')

    # Fourth plot: leg rotation
    axs[1,1].set_title('leg rotation')
    axs[1,1].hist(data['leg_gyr_x'], bins = 100, alpha = 0.5, label='x')
    axs[1,1].hist(data['leg_gyr_y'], bins = 100, alpha = 0.5, label='y')
    axs[1,1].hist(data['leg_gyr_z'], bins = 100, alpha = 0.5, label='z')
    axs[1,1].set_xlabel("rotation (rad/s)")
    axs[1,1].set_ylabel("frequency")
    axs[1,1].legend(loc = 'upper left')

    # Set common x-label


    plt.savefig("./figures/" + session_name + "_distributions")

    # Show plot
    #plt.show()

# %%
# iterate over sessions
names = ['tunde', 'chris', 'aron']
cols = ['time', 'arm_gyr_x', 'arm_gyr_y', 'arm_gyr_z', 'arm_acc_x', 'arm_acc_y', 'arm_acc_z', 'leg_gyr_x', 'leg_gyr_y', 'leg_gyr_z', 'leg_acc_x', 'leg_acc_y', 'leg_acc_z', 'dist', 'pace', 'HR']

for name in names:
    for session_number in range(1,4):
        path = "./measurement-data/processed/" + name + "/nan_session_" + str(session_number) + ".csv"
        data = pd.read_csv(path, names=cols, header = 0)
        session_name = name + "_" + str(session_number)

        #create_movement_plot(data, session_name)
        #create_performance_plot(data, session_name)
        create_distribution_plot(data, session_name)

# %%
cols = ['time', 'arm_gyr_x', 'arm_gyr_y', 'arm_gyr_z', 'arm_acc_x', 'arm_acc_y', 'arm_acc_z', 'leg_gyr_x', 'leg_gyr_y', 'leg_gyr_z', 'leg_acc_x', 'leg_acc_y', 'leg_acc_z', 'dist', 'pace', 'HR', 'exp_lvl', 'session_id']

path = "./measurement-data/full_data.csv"
data = pd.read_csv(path, names=cols, header = 0)
session_name = "full_data"

create_distribution_plot(data, session_name)

# %%
import time

# %%
data['time']
# Out:
# 0       00:00:00.000
# 1       00:00:00.100
# 2       00:00:00.200
# 3       00:00:00.300
# 4       00:00:00.400
#             ...
# 2996    00:04:59.600
# 2997    00:04:59.700
# 2998    00:04:59.800
# 2999    00:04:59.900
# 3000    00:05:00.000
# Name: time, Length: 3001, dtype: object

# %%
names = [('tunde', 0), ('chris', 1), ('aron', 2)]
cols = ['time', 'arm_gyr_x', 'arm_gyr_y', 'arm_gyr_z', 'arm_acc_x', 'arm_acc_y', 'arm_acc_z', 'leg_gyr_x', 'leg_gyr_y', 'leg_gyr_z', 'leg_acc_x', 'leg_acc_y', 'leg_acc_z', 'dist', 'pace', 'HR']

datasets = []

experience_levels = {'tunde_1': 0, 'tunde_2': 1, 'tunde_3':1, 'aron_1': 0, 'aron_2':1, 'aron_3':1, 'chris_1':3, 'chris_2':3, 'chris_3':3}


for name, person_id in names:
    for session_number in range(1,4):
        path = "./measurement-data/processed/" + name + "/nan_session_" + str(session_number) + ".csv"
        data = pd.read_csv(path, names=cols, header = 0)
        session_name = name + "_" + str(session_number)
        session_id = (str(person_id) + str(session_number))

        data['experience_level'] = experience_levels[session_name]
        data['session_id'] = session_id

        datasets.append(data)

full_dataset = pd.concat(datasets, axis = 0)

full_dataset
# Out:
#               time  arm_gyr_x  arm_gyr_y  arm_gyr_z  arm_acc_x  arm_acc_y  \
# 0     00:00:00.000  -0.002570   0.019913   0.006774  -5.447741   4.000386
# 1     00:00:00.100   0.001378  -0.014144   0.000395  -5.519722   4.025995
# 2     00:00:00.200  -0.003601   0.012185  -0.005429  -5.479969   4.049260
# 3     00:00:00.300   0.002071  -0.006182   0.001887  -5.528513   4.034934
# 4     00:00:00.400   0.025872   0.048854  -0.052939  -5.409436   4.235622
# ...            ...        ...        ...        ...        ...        ...
# 2996  00:04:59.600   0.026425  -0.307079  -0.394813   3.107732   9.841075
# 2997  00:04:59.700   0.142612  -0.121331   0.043416   2.654789   9.501626
# 2998  00:04:59.800   0.063978  -0.203084   0.362551   2.873829   9.728135
# 2999  00:04:59.900  -0.037796  -0.248960   0.354951   2.917403   9.083022
# 3000  00:05:00.000        NaN        NaN        NaN        NaN        NaN
#
#       arm_acc_z  leg_gyr_x  leg_gyr_y  leg_gyr_z  leg_acc_x  leg_acc_y  \
# ...

# %%
full_dataset.to_csv("measurement-data/full_data.csv")

# %% [markdown]
# ### Smoothing data by aggregation

# %%
#set up timebins
timestart = data['time'][0]
timeend = data['time'][rows-1]

dt = 0.1

timebins = pd.DataFrame(np.arange(timestart, timeend, dt), columns = ['bin_start'])
timebins['bin_end'] = timebins['bin_start'].shift(-1)
timebins['bin_end'][len(timebins)-1] = timebins['bin_end'][len(timebins)-1] + 5
timebins.loc[len(timebins) -1, 'bin_end'] = timebins.loc[len(timebins) -2, 'bin_end'] + dt *100
timebins['bin_number'] = range(len(timebins))

timebins
# Out:
#      bin_start    bin_end  bin_number
# 0     0.003206   0.103206           0
# 1     0.103206   0.203206           1
# 2     0.203206   0.303206           2
# 3     0.303206   0.403206           3
# 4     0.403206   0.503206           4
# ..         ...        ...         ...
# 106  10.603206  10.703206         106
# 107  10.703206  10.803206         107
# 108  10.803206  10.903206         108
# 109  10.903206  11.003206         109
# 110  11.003206  21.003206         110
#
# [111 rows x 3 columns]

# %%
def find_bin_number(timestamp, bins_df):
    bin_row = bins_df[(bins_df['bin_start'] <= timestamp) & (bins_df['bin_end'] > timestamp)]
    if not bin_row.empty:
        return bin_row.iloc[0]['bin_number']
    else:
        return np.nan  # if no bin is found (shouldn't happen if bins cover all timestamps)

# %%
#find bin numbers for data
data['bin_number'] = data['time'].apply(find_bin_number, bins_df=timebins)

# %%
# average over bins
aggregated_data = data.groupby('bin_number').agg('mean')

# %%
aggregated_data
# Out:
#                  time         x         y         z       abs
# bin_number
# 0.0          0.050915  0.303575 -0.202253  0.915530  1.149459
# 1.0          0.151091  0.240573  0.549653 -0.109209  0.726034
# 2.0          0.251271 -0.358547  0.635541  1.071751  1.476985
# 3.0          0.351451 -0.322443  0.852016  2.221338  2.641003
# 4.0          0.451631 -1.817923 -0.596649  1.608783  2.506522
# ...               ...       ...       ...       ...       ...
# 106.0       10.653292  0.001986  0.082539  0.103157  0.227757
# 107.0       10.751087  0.010704  0.011135  0.107821  0.241663
# 108.0       10.851267  0.278624  0.006424 -0.147562  0.334280
# 109.0       10.951447  0.149101 -0.045724 -0.623598  0.956028
# 110.0       11.006308  0.155224  0.041901  0.527553  0.551725
#
# [111 rows x 5 columns]

# %%
plt.figure()
size = 10
mark = "+"
plt.figure(figsize=(12,8))
plt.title("smoothed Test Data")
plt.plot(aggregated_data['time'], aggregated_data['x'], label = 'x')
plt.plot(aggregated_data['time'], aggregated_data['y'], label = 'y')
plt.plot(aggregated_data['time'], aggregated_data['z'], label = 'z')
plt.plot(aggregated_data['time'], aggregated_data['abs'], label = 'abs')
plt.xlabel("time")
plt.ylabel("acceleration (m/s^2)")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
data
# Out:
#            time         x         y         z       abs  bin_number
# 0      0.003206  0.000000  0.000000  0.000000  0.000000         0.0
# 1      0.008071  0.227786 -0.016674  0.099801  0.249248         0.0
# 2      0.012747  0.458751 -0.049896  0.257033  0.528213         0.0
# 3      0.017517  0.718220 -0.102618  0.436018  0.846453         0.0
# 4      0.022288  0.917469 -0.131076  0.660093  1.137828         0.0
# ...         ...       ...       ...       ...       ...         ...
# 2303  10.989611 -0.207720  0.120852 -0.054945  0.246520       109.0
# 2304  10.994382 -0.146109  0.149413  0.065645  0.219046       109.0
# 2305  10.999152 -0.024265  0.099703  0.260825  0.280284       109.0
# 2306  11.003922  0.117745  0.045929  0.435184  0.453165       110.0
# 2307  11.008693  0.192703  0.037873  0.619921  0.650285       110.0
#
# [2308 rows x 6 columns]

# %%
data_fft_x = np.fft.fft(data['x'])

# %%
plt.plot(data_fft_x)
# Out:
# c:\Users\tunde\ML4QS-group60\.venv\lib\site-packages\matplotlib\cbook\__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
data_fft_x

# %%
data_ifft_x = np.fft.ifft(data_fft_x)

# %%
plt.plot(data_ifft_x, label="fft->ifft")
plt.plot(data['x'], label='og')
# Out:
# c:\Users\tunde\ML4QS-group60\.venv\lib\site-packages\matplotlib\cbook\__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
